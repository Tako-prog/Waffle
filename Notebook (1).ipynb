# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tabitha** <br>
# Teacher

# %% [markdown]
# *I am looking for a more challenging career*

# %% [markdown]
# ### The code it supposed to add two numbers together

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))
 
sum = a + b
 
print("sum:", sum)

# %% [markdown]
# 1. First ordered list item
# 2. Another item
# ⋅⋅* Unordered sub-list.
# 1. Actual numbers don't matter, just that it's a number
# ⋅⋅1. Ordered sub-list
# 4. And another item.<br>
# [A website I found helpful](https://medium.com/analytics-vidhya/the-jupyter-notebook-formatting-guide-873ab39f765e)
